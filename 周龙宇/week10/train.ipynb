# %%
import torch
import torch.nn as nn
import numpy as np
import math
import random
import os
import re

"""
基于pytorch的only decoder语言模型
"""
import torch
import torch.nn as nn
import math
import torch.nn.functional as F
import copy

from new_nnbert import Encoder

#加载字表
def build_vocab(vocab_path):
    vocab = {"<pad>":0}
    with open(vocab_path, encoding="utf8") as f:
        for index, line in enumerate(f):
            char = line[:-1]       #去掉结尾换行符
            vocab[char] = index + 1 #留出0位给pad token
    return vocab

#加载语料
def load_corpus(path):
    corpus = ""
    with open(path, encoding="gbk") as f:
        for line in f:
            corpus += line.strip()
    return corpus

#随机生成一个样本
#从文本中截取随机窗口，前n个字作为输入，最后一个字作为输出
def build_sample(vocab, window_size, corpus):
    start = random.randint(0, len(corpus) - 1 - window_size)
    end = start + window_size
    window = corpus[start:end]
    target = corpus[start + 1:end + 1]  #输入输出错开一位
    # print(window, target)
    x = [vocab.get(word, vocab["<UNK>"]) for word in window]   #将字转换成序号
    y = [vocab.get(word, vocab["<UNK>"]) for word in target]
    return x, y

#建立数据集
#sample_length 输入需要的样本数量。需要多少生成多少
#vocab 词表
#window_size 样本长度
#corpus 语料字符串
def build_dataset(sample_length, vocab, window_size, corpus):
    dataset_x = []
    dataset_y = []
    for i in range(sample_length):
        x, y = build_sample(vocab, window_size, corpus)
        dataset_x.append(x)
        dataset_y.append(y)
    return torch.LongTensor(dataset_x), torch.LongTensor(dataset_y)

#建立模型
def build_model(vocab, char_dim):
    # model = LanguageModel(char_dim, vocab)
    model = Encoder(vocab, char_dim, 2, 12)
    return model

#文本生成测试代码
def generate_sentence(openings, model, vocab, window_size):
    reverse_vocab = dict((y, x) for x, y in vocab.items())
    model.eval()
    src_mask = torch.tril(torch.ones(window_size, window_size)).bool().cuda()
    with torch.no_grad():
        pred_char = ""
        #生成了换行符，或生成文本超过30字则终止迭代
        while pred_char != "\n" and len(openings) <= 30:
            openings += pred_char
            x = [vocab.get(char, vocab["<UNK>"]) for char in openings[-window_size:]]
            x = torch.LongTensor([x])
            if torch.cuda.is_available():
                x = x.cuda()
            
            y = model(x, y=None, mask=src_mask)[0]
            # print(y.shape)
            index = sampling_strategy(y[-1])
            pred_char = reverse_vocab[index]
    return openings

def sampling_strategy(prob_distribution):
    if random.random() > 0.1:
        strategy = "greedy"
    else:
        strategy = "sampling"
    if strategy == "greedy":
        return int(torch.argmax(prob_distribution))
    elif strategy == "sampling":
        prob_distribution = prob_distribution.cpu().numpy()
        return np.random.choice(list(range(len(prob_distribution))), p=prob_distribution)


#计算文本ppl
def calc_perplexity(sentence, model, vocab, window_size):
    prob = 0
    model.eval()
    with torch.no_grad():
        for i in range(1, len(sentence)):
            start = max(0, i - window_size)
            window = sentence[start:i]
            x = [vocab.get(char, vocab["<UNK>"]) for char in window]
            x = torch.LongTensor([x])
            target = sentence[i]
            target_index = vocab.get(target, vocab["<UNK>"])
            if torch.cuda.is_available():
                x = x.cuda()
            pred_prob_distribute = model(x)[0][-1]
            target_prob = pred_prob_distribute[target_index]
            prob += math.log(target_prob, 10)
    return 2 ** (prob * ( -1 / len(sentence)))


def train(corpus_path, save_weight=False):
    epoch_num = 50        #训练轮数
    batch_size = 64       #每次训练样本个数
    train_sample = 50000  #每轮训练总共训练的样本总数
    char_dim = 768        #每个字的维度
    window_size = 10       #样本文本长度
    vocab = build_vocab("vocab.txt")       #建立字表
    corpus = load_corpus(corpus_path)     #加载语料
    model = build_model(vocab, char_dim)    #建立模型
    src_mask = torch.tril(torch.ones(window_size, window_size)).bool().cuda()
    # print(model)
    if torch.cuda.is_available():
        model = model.cuda()
    optim = torch.optim.Adam(model.parameters(), lr=0.001)   #建立优化器
    print("文本词表模型加载完毕，开始训练")
    for epoch in range(epoch_num):
        print(f'当前epoch:{epoch}')
        model.train()
        watch_loss = []
        for batch in range(int(train_sample / batch_size)):
            x, y = build_dataset(batch_size, vocab, window_size, corpus) #构建一组训练样本
            # print(x.shape, y.shape)
            if torch.cuda.is_available():
                x, y = x.cuda(), y.cuda()
            optim.zero_grad()    #梯度归零
            loss = model(x, y, src_mask)   #计算loss
            # print(loss.item())
            loss.backward()      #计算梯度
            optim.step()         #更新权重
            watch_loss.append(loss.item())
        print("=========\n第%d轮平均loss:%f" % (epoch + 1, np.mean(watch_loss)))
        print(generate_sentence("让他在半年之前，就不能做出", model, vocab, window_size))
        print(generate_sentence("李慕站在山路上，深深的呼吸", model, vocab, window_size))
    if not save_weight:
        return
    else:
        base_name = os.path.basename(corpus_path).replace("txt", "pth")
        model_path = os.path.join("model", base_name)
        torch.save(model.state_dict(), model_path)
        return
if __name__ == "__main__":
    # build_vocab_from_corpus("corpus/all.txt")
    train("corpus.txt", False)
# Out:
# 文本词表模型加载完毕，开始训练
# 当前epoch:0
# =========
# 第1轮平均loss:4.467230
# 让他在半年之前，就不能做出来，是他是不能在这里，他每一个月，他
# 李慕站在山路上，深深的呼吸了一个人，但他们对于他们的，他们的身
# 当前epoch:1
# =========
# 第2轮平均loss:4.117742
# 让他在半年之前，就不能做出来安全，但这些日子，李慕的身体，李慕
# 李慕站在山路上，深深的呼吸声，李慕的身体，李慕就是一个月，但也
# 当前epoch:2
# =========
# 第3轮平均loss:4.032398
# 让他在半年之前，就不能做出了一个人，他们和李慕，说道：“你们不
# 李慕站在山路上，深深的呼吸口气，逐渐的消耗，他们出现在他的身体
# 当前epoch:3
# =========
# 第4轮平均loss:3.989936
# 让他在半年之前，就不能做出了一些，他们的事情，他们的，他们的身
# 李慕站在山路上，深深的呼吸收了一些，身体，也不能再次出现在的，
# 当前epoch:4
# =========
# 第5轮平均loss:3.945637
# 让他在半年之前，就不能做出步。李慕看到李慕，说道：“你们不是我
# 李慕站在山路上，深深的呼吸，说道：“苏！”李慕道：“你们不知道
# 当前epoch:5
# =========
# 第6轮平均loss:3.906239
# 让他在半年之前，就不能做出的事情，他。”李慕道：“你们知道姐姐
# 李慕站在山路上，深深的呼吸风，说道：“你们是我们的，那么多好，
# 当前epoch:6
# =========
# 第7轮平均loss:3.866904
# 让他在半年之前，就不能做出这么快，他们的，李慕不是一个人，不是
# 李慕站在山路上，深深的呼吸，一声，说道：“你们通过这种事件事情
# 当前epoch:7
# =========
# 第8轮平均loss:3.832428
# 让他在半年之前，就不能做出了这么多，他们也也按照她们的的实力，
# 李慕站在山路上，深深的呼吸声，说道：“你们不是你们的，你们也不
# 当前epoch:8
# =========
# 第9轮平均loss:3.809628
# 让他在半年之前，就不能做出来的事情，但别人都是一个名字，但也是
# 李慕站在山路上，深深的呼吸口气，说道：“你是什么了，我们的，我
# 当前epoch:9
# =========
# 第10轮平均loss:3.788001
# 让他在半年之前，就不能做出来，他们的，他每一个人都是一个小的，
# 李慕站在山路上，深深的呼吸声道：“我们的，你们不是什么意思？”
# 当前epoch:10
# =========
# 第11轮平均loss:3.756911
# 让他在半年之前，就不能做出一个不少，但他们也不是一个人，这种种
# 李慕站在山路上，深深的呼吸声，说道：“你们不是你们的，你们不是
# 当前epoch:11
# =========
# 第12轮平均loss:3.736280
# 让他在半年之前，就不能做出一个月内，李慕的身体，李慕的身体，一
# 李慕站在山路上，深深的呼吸口气，说道：“我们的真实力，我们不会
# 当前epoch:12
# =========
# 第13轮平均loss:3.727814
# 让他在半年之前，就不能做出来灵玉，就是修行了，他们的身体，也不
# 李慕站在山路上，深深的呼吸，他的身体，他的身体，也不知道，这是
# 当前epoch:13
# =========
# 第14轮平均loss:3.707531
# 让他在半年之前，就不能做出什么事情，我们也不是你们的，你们的身
# 李慕站在山路上，深深的呼吸口气，说道：“你们是不是我们的，你们
# 当前epoch:14
# =========
# 第15轮平均loss:3.691797
# 让他在半年之前，就不能做出这种情况，她们的脾性的，女皇的身体，
# 李慕站在山路上，深深的呼吸了口气，说道：“你们怎么办，我不想让
# 当前epoch:15
# =========
# 第16轮平均loss:3.673325
# 让他在半年之前，就不能做出这种情况，他们的也不会有这么多的事情
# 李慕站在山路上，深深的呼吸口气，说道：“我可以不再说，我们就说
# 当前epoch:16
# =========
# 第17轮平均loss:3.660260
# 让他在半年之前，就不能做出这种事情，我就是你们的意思，我们一个
# 李慕站在山路上，深深的呼吸收起来。李慕的时候，他们的修行者，也
# 当前epoch:17
# =========
# 第18轮平均loss:3.638364
# 让他在半年之前，就不能做出这么多的，就是他们的修行者，也不能让
# 李慕站在山路上，深深的呼吸了一个，说道：“你们的人，你们不要不
# 当前epoch:18
# =========
# 第19轮平均loss:3.635621
# 让他在半年之前，就不能做出的，他们的事情，每一个人都是一座小城
# 李慕站在山路上，深深的呼吸口气，说道：“说，几个月前，他们就是
# 当前epoch:19
# =========
# 第20轮平均loss:3.624879
# 让他在半年之前，就不能做出你们的事情，我们就是一个人的，我们就
# 李慕站在山路上，深深的呼吸引了一口气，说道：“你们是不是说，我
# 当前epoch:20
# =========
# 第21轮平均loss:3.620179
# 让他在半年之前，就不能做出一个人，就算是神秘的，已经有了一个人
# 李慕站在山路上，深深的呼吸声响，李慕心中暗示意，他的目光望向前
# 当前epoch:21
# =========
# 第22轮平均loss:3.599232
# 让他在半年之前，就不能做出这种事情，他们的身上的气息，则是他们
# 李慕站在山路上，深深的呼吸，他们的身边的一旁，说道：“你是我们
# 当前epoch:22
# =========
# 第23轮平均loss:3.586233
# 让他在半年之前，就不能做出什么多事情，他们的身份，也不是一样的
# 李慕站在山路上，深深的呼吸了一些，他承诺的身体，也不是一样的，
# 当前epoch:23
# =========
# 第24轮平均loss:3.583941
# 让他在半年之前，就不能做出合理。”李慕道：“你不是我的，你们不
# 李慕站在山路上，深深的呼吸口气，说道：“我们不是不是我的，你们
# 当前epoch:24
# =========
# 第25轮平均loss:3.555952
# 让他在半年之前，就不能做出这么多的事情，但他们的身体，也不会不
# 李慕站在山路上，深深的呼吸了口气，说道：“这是什么，不是我呢？
# 当前epoch:25
# =========
# 第26轮平均loss:3.560370
# 让他在半年之前，就不能做出这种事情，他们的心宗，也不会有什么好
# 李慕站在山路上，深深的呼吸引，李慕的身体一颤，说道：“你们是什
# 当前epoch:26
# =========
# 第27轮平均loss:3.544786
# 让他在半年之前，就不能做出来享受这样的事情，李慕还是不是他们的
# 李慕站在山路上，深深的呼吸声，说道：“我们是你们的意思，我们不
# 当前epoch:27
# =========
# 第28轮平均loss:3.535671
# 让他在半年之前，就不能做出这种事情，我们不会有什么好事，我们不
# 李慕站在山路上，深深的呼吸吸收了一口，说道：“你们不是不是，我
# 当前epoch:28
# =========
# 第29轮平均loss:3.530308
# 让他在半年之前，就不能做出一个人。”李慕点了点头，说道：“我们
# 李慕站在山路上，深深的呼吸吸口气，说道：“我们两个人，你们是我
# 当前epoch:29
# =========
# 第30轮平均loss:3.528414
# 让他在半年之前，就不能做出这种，不是大周朝廷的新党，也不会有人
# 李慕站在山路上，深深的呼吸，他们的身体，也不会有人怀疑，他们的
# 当前epoch:30
# =========
# 第31轮平均loss:3.521496
# 让他在半年之前，就不能做出来了。”李慕点了点头，说道：“我们呢
# 李慕站在山路上，深深的呼吸引，李慕冰冷了一下，说道：“我们的事
# 当前epoch:31
# =========
# 第32轮平均loss:3.517501
# 让他在半年之前，就不能做出这种事情的，有人能够感应到，但从来没
# 李慕站在山路上，深深的呼吸一声，说道：“你们是不是你们的事情，
# 当前epoch:32
# =========
# 第33轮平均loss:3.505521
# 让他在半年之前，就不能做出来的，我们的事情，我们也不会是一样的
# 李慕站在山路上，深深的呼吸声，说道：“我不知道，你问你怎么办？
# 当前epoch:33
# =========
# 第34轮平均loss:3.496183
# 让他在半年之前，就不能做出的事情，他们也不会有什么好问题？”李
# 李慕站在山路上，深深的呼吸，他们的身体一阵，便是一道白光，从李
# 当前epoch:34
# =========
# 第35轮平均loss:3.499546
# 让他在半年之前，就不能做出这种事情，如果不是一个人，他们保护法
# 李慕站在山路上，深深的呼吸口气，说道：“我们多谢陛下，我们一会
# 当前epoch:35
# =========
# 第36轮平均loss:3.492178
# 让他在半年之前，就不能做出这种事情，他们的修为，也不是第六境的
# 李慕站在山路上，深深的呼吸声，说道：“你们在神都，你们的身上，
# 当前epoch:36
# =========
# 第37轮平均loss:3.476205
# 让他在半年之前，就不能做出了这种事情，我先去给你们，我们两个人
# 李慕站在山路上，深深的呼吸，李慕的身体，也不懂得不能让他们一个
# 当前epoch:37
# =========
# 第38轮平均loss:3.474822
# 让他在半年之前，就不能做出这种事情，他们的身体，也不能再看他一
# 李慕站在山路上，深深的呼吸，撩拨拨着李慕的胳膊，说道：“你们是
# 当前epoch:38
# =========
# 第39轮平均loss:3.468846
# 让他在半年之前，就不能做出这种事情，李慕也不用担心，他们不是不
# 李慕站在山路上，深深的呼吸，他的身体，也不能再提升青成子，他们
# 当前epoch:39
# =========
# 第40轮平均loss:3.467624
# 让他在半年之前，就不能做出这种事情，他们的确是一个人，也不能再
# 李慕站在山路上，深深的呼吸，李慕的声音音音，李慕的时候，李慕就
# 当前epoch:40
# =========
# 第41轮平均loss:3.464016
# 让他在半年之前，就不能做出这种事情，他们也不是他们的对手，也不
# 李慕站在山路上，深深的呼吸，他们也不能再从中书省，他们才能够感
# 当前epoch:41
# =========
# 第42轮平均loss:3.462924
# 让他在半年之前，就不能做出这种事情，哪怕是他们的修为，他们是不
# 李慕站在山路上，深深的呼吸的，李慕的身体，也不是随意为了他们延
# 当前epoch:42
# =========
# 第43轮平均loss:3.461804
# 让他在半年之前，就不能做出了这种事情，看着李慕，其实也想要和她
# 李慕站在山路上，深深的呼吸一声，说道：“我们就来了，我们也不会
# 当前epoch:43
# =========
# 第44轮平均loss:3.452377
# 让他在半年之前，就不能做出这种事情，他们就不会有人能够做到的，
# 李慕站在山路上，深深的呼吸，李慕的身体，从他们身上穿过，李慕的
# 当前epoch:44
# =========
# 第45轮平均loss:3.446163
# 让他在半年之前，就不能做出一些，就是一个郡城，都是一个人，都是
# 李慕站在山路上，深深的呼吸，李慕心中暗叹息，说道：“我们去看看
# 当前epoch:45
# =========
# 第46轮平均loss:3.441936
# 让他在半年之前，就不能做出一种种事情，他们也不能再和他们一起去
# 李慕站在山路上，深深的呼吸声，李慕的身上的气息，在他的身上，也
# 当前epoch:46
# =========
# 第47轮平均loss:3.427910
# 让他在半年之前，就不能做出一个决定，他们的确是一件好主事，他们
# 李慕站在山路上，深深的呼吸口。“这是我们的职责，你们的亲自出手
# 当前epoch:47
# =========
# 第48轮平均loss:3.440348
# 让他在半年之前，就不能做出这种事情，他事情，不是因为他们的身份
# 李慕站在山路上，深深的呼吸急促进去，李慕的身体，说道：“你们们
# 当前epoch:48
# =========
# 第49轮平均loss:3.419573
# 让他在半年之前，就不能做出这种事情，他们也不会有什么事情吗？”
# 李慕站在山路上，深深的呼吸声音，忽然从李慕手中的那一张符箓，远
# 当前epoch:49
# =========
# 第50轮平均loss:3.425895
# 让他在半年之前，就不能做出了一个好戏，但也不能让他们一个人的修
# 李慕站在山路上，深深的呼吸，不知道是因为掌教，但也是他们的对手
